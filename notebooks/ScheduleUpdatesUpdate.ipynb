# %% [markdown]
# # Code Downloads latest excel file and updates current updates file

# %% [markdown]
# ### Clean old updates

# %%
import pandas as pd

# %%
ideal_promises = pd.read_excel('../assets/data/Promises.xlsx')

# %%
ideal_promises.to_excel('newPromises.xlsx', index=None)

# %%
ideal_promises.Promise = ideal_promises.Promise.apply(lambda x: x.lower().strip())

# %%
ideal_promises['Sub promise'] = ideal_promises['Sub promise'].apply(lambda x: x.lower().strip())

# %%
import requests
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQi5APAZW3CvMw-8LUdCFxdg5CIEjAB-EnnKHe6kzMxQyHDWZbZToW3kLSvpDMcEQZ34o6nOIxbMcwm/pub?output=xlsx"
googleFormUpdates = requests.get(url)
open('../assets/data/googleFormUpdates.xlsx', 'wb').write(googleFormUpdates.content)
updates = pd.read_excel('../assets/data/googleFormUpdates.xlsx')
updates = updates.rename(columns={'Promise ': 'Promise', 'SubPromise ': 'SubPromise'})

# %%
# updates = pd.read_excel('../assets/data/old/updates.xlsx')

# %%
updates.columns
# Out:
# Index(['Timestamp', 'Promise', 'Subpromise', 'Date of Update', 'Status',
#        'Description', 'Title', 'Proof Documents/Images', 'Proof URL',
#        'Email Address', 'Approved'],
#       dtype='object')

# %%
updates['Promise'].fillna('None', inplace=True)
updates['Promise'] = updates['Promise'].apply(lambda x: x.lower().strip())

# %%
ideal_promises.head()
# Out:
#    Sr No          Promise                                        Sub promise  \
# 0      1  jan lokpal bill  aam aadmi party resolves to legislate the delh...
# 1      1  jan lokpal bill  this will ensure a time-bound investigation in...
# 2      1  jan lokpal bill  the delhi lokpal will have the power to initia...
# 3      1  jan lokpal bill  a citizens’ charter shall be introduced in all...
# 4      1  jan lokpal bill  whistleblowers will be provided protection and...
#
#                                           Unnamed: 3              Department  \
# 0  Jan Lokpal Bill__Aam Aadmi Party resolves to l...          Delhi Assembly
# 1  Jan Lokpal Bill__This will ensure a time-bound...  Anti Corruption Bureau
# 2  Jan Lokpal Bill__The Delhi Lokpal will have th...          Delhi Assembly
# 3  Jan Lokpal Bill__A Citizens’ Charter shall be ...          Delhi Assembly
# 4  Jan Lokpal Bill__Whistleblowers will be provid...      Finance Department
#
#       Outcome  __
# 0  Governance NaN
# 1  Governance NaN
# 2  Governance NaN
# 3  Governance NaN
# 4  Governance NaN

# %%
correct_subpromises = ideal_promises['Sub promise'].unique()

# %%
correct_promises = set([promise.lower() for promise in ideal_promises.Promise.unique()])

# %%
assert len(correct_promises) == 70

# %%
updates_promises = set([promise.lower() for promise in updates['Promise'].unique()])

# %%
errors = updates_promises - correct_promises

# %%
from fuzzywuzzy import process

# %%
corrections = {k:process.extract(k, correct_promises, limit=1)[0][0] for k in errors}

# %%
corrections
# Out:
# {'transparency in schools admission': 'tranparency in school admissions',
#  'large scale expansion inbus service': 'large scale expansion in bus services',
#  'increased spending on education and healthcare': 'increase spending on education & healthcare',
#  'delhi janlokpal bill:': 'delhi to be made a trade and retail hub',
#  'promote rainwater harvesting': 'promote rain water harvesting',
#  'contractual posts to be regularized': 'contractual posts to be regularised',
#  'water as a right': 'water as right',
#  'delhi to be made solar city': 'delhi to be made a solar city',
#  'just and fair policy for e rickshaws': 'just and fair policy for e-rickshaws',
#  'five hundred new government schools': 'ramp up government schools to provide quality education',
#  'justice for the victims of 1984': 'justice for victims of anti-sikh 1984 carnage',
#  'build 2,00,000 public toilets': 'build 2 lakh public toilets',
#  'water from munak canaal': 'water from munak canal',
#  'wifi delhi': 'wi-fi delhi',
#  'delhi to be startup hub': 'delhi to be start up hub',
#  'none': 'crack down on water mafia',
#  'higher education gurantee scheme': 'higher education guarantee scheme',
#  'cctvs in public spaces and buses': "cctv's in public spaces & buses",
#  'crackdown on water mafia': 'crack down on water mafia',
#  'fair and transparent water pricing': 'fair transparent water pricing',
#  'fair arrangement for auto drivers': 'fair arrangement for autodrivers',
#  'twenty new degree colleges': '20 new degree colleges'}

# %%
maps = {k:k for k in updates['Promise'].unique()}
maps.update(corrections)

# %%
updates['Promise'] = updates['Promise'].map(maps)

# %%
updates['SubPromise'].fillna('None', inplace=True)
updates['SubPromise'] = updates['SubPromise'].apply(lambda x: x.split('__')[-1].lower().strip())

# %%
updates.head()
# Out:
#                 Timestamp                              Promise  \
# 0 2020-02-03 18:38:44.301          Delhi To be Made Solar City
# 1 2020-02-04 15:33:03.322           Twenty New Degree Colleges
# 2 2020-02-04 16:34:14.222           Twenty New Degree Colleges
# 3 2020-02-04 16:53:02.346  Five Hundred New Government Schools
# 4 2020-02-04 17:14:40.167  Five Hundred New Government Schools
#
#                                           SubPromise Date of Update  \
# 0  we are committed to ensuring that 20 percent o...     2018-08-05
# 1  further we will double the existing seat capac...     2019-08-24
# 2  further we will double the existing seat capac...     2017-08-18
# 3  aap will build 500 new schools with a special ...     2020-01-09
# 4  aap will build 500 new schools with a special ...     2020-04-08
#
#         Status                                        Description  \
# 0  In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1  In Progress  Building of new campuses for Ambedkar universi...
# 2  In Progress  New University Campus for DTU opened up in Viv...
# 3         Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4         Done  Details of Swimming pools in two school situat...
#
#                                                Title  \
# 0  Solarize Dwarka launched in BSES Rajdhani regi...
# 1                   Ambedkar University New Campuses
# 2                                 East Campus of DTU
# 3                   AAP builds 20,000 new classrooms
# 4  Delhi Govt Schools in West Vinod Nagar & Mayur...
#
#                               Proof Documents/Images  \
# 0  https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1  https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2  https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3  https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4  https://drive.google.com/open?id=1wp2zNWzsOGSi...
#
#                                            Proof URL  \
# 0                              http://solarbses.com/
# 1  https://www.thehindu.com/news/cities/Delhi/aud...
# 2  https://www.hindustantimes.com/delhi-news/east...
# 3  https://www.hindustantimes.com/education/aap-g...
# 4  https://timesofindia.indiatimes.com/city/delhi...
#
#               Email Address Approved
# 0                       NaN      Yes
# 1                       NaN      Yes
# 2  adityapaul.aap@gmail.com      Yes
# 3  adityapaul.aap@gmail.com      Yes
# 4  adityapaul.aap@gmail.com      Yes

# %%
subpromise_errors = set(updates['SubPromise'].unique()) - set(correct_subpromises)

# %%
corrections = {k:process.extract(k, correct_subpromises, limit=2) for k in subpromise_errors}

# %%
len(subpromise_errors)
subpromise_errors
# Out:
# {'none'}

# %%
# updates[updates['SubPromise '].isin(subpromise_errors)].to_excel('soumya_corrections.xlsx')
# subpromise corrects

# %%
subpromise_error_indices = updates[updates['SubPromise'].isin(subpromise_errors)].index

# %%
updates = updates.drop(subpromise_error_indices)

# %%
updates.to_excel('correctedGoogleFormUpdates.xlsx')

# %%
updates.shape
# Out:
# (252, 11)

# %%
ideal_promises
# Out:
#      Sr No                               Promise  \
# 0        1                       jan lokpal bill
# 1        1                       jan lokpal bill
# 2        1                       jan lokpal bill
# 3        1                       jan lokpal bill
# 4        1                       jan lokpal bill
# ..     ...                                   ...
# 219     69  promoting punjabi, sanskrit and urdu
# 220     69  promoting punjabi, sanskrit and urdu
# 221     69  promoting punjabi, sanskrit and urdu
# 222     70  preserving our heritage & literature
# 223     70  preserving our heritage & literature
#
#                                            Sub promise  \
# 0    aam aadmi party resolves to legislate the delh...
# 1    this will ensure a time-bound investigation in...
# 2    the delhi lokpal will have the power to initia...
# 3    a citizens’ charter shall be introduced in all...
# 4    whistleblowers will be provided protection and...
# ..                                                 ...
# 219  an adequate number of teachers will be employe...
# 220  research in urdu and punjabi shall be encourag...
# 221  study and research in sanskrit will also be en...
# 222  the delhi public library network, which presen...
# 223  a public library or community-reading space wi...
#
#                                             Unnamed: 3  \
# 0    Jan Lokpal Bill__Aam Aadmi Party resolves to l...
# 1    Jan Lokpal Bill__This will ensure a time-bound...
# 2    Jan Lokpal Bill__The Delhi Lokpal will have th...
# 3    Jan Lokpal Bill__A Citizens’ Charter shall be ...
# 4    Jan Lokpal Bill__Whistleblowers will be provid...
# ..                                                 ...
# 219  Promoting Punjabi, Sanskrit and Urdu__An adequ...
# 220  Promoting Punjabi, Sanskrit and Urdu__Research...
# 221  Promoting Punjabi, Sanskrit and Urdu__Study an...
# 222  Preserving Our Heritage & Literature__The Delh...
# 223  Preserving Our Heritage & Literature__A public...
#
#                                 Department     Outcome  __
# 0                           Delhi Assembly  Governance NaN
# 1                   Anti Corruption Bureau  Governance NaN
# 2                           Delhi Assembly  Governance NaN
# 3                           Delhi Assembly  Governance NaN
# 4                       Finance Department  Governance NaN
# ..                                     ...         ...  ..
# 219  Art, Culture and Languages Department     Culture NaN
# 220  Art, Culture and Languages Department     Culture NaN
# 221  Art, Culture and Languages Department     Culture NaN
# 222                   Education Department     Culture NaN
# 223                   Education Department     Culture NaN
#
# [224 rows x 7 columns]

# %% [markdown]
# ### Merge with old promises

# %%
oldupdates = pd.read_excel('../assets/data/old/updates.xlsx')
oldupdates.shape
oldupdates.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'Promise', 'SubPromise', 'Date of Update',
#        'Status', 'Description', 'Title', 'Proof Documents/Images', 'Proof URL',
#        'Email Address', 'Approved'],
#       dtype='object')

# %%
oldupdates['Promise'] = oldupdates['Promise'].apply(lambda x: x.lower().strip())

# %%
oldupdates
# Out:
#      Unnamed: 0               Timestamp  \
# 0             0 2020-02-03 18:38:44.301
# 1             1 2020-02-04 15:33:03.322
# 2             2 2020-02-04 16:34:14.222
# 3             3 2020-02-04 16:53:02.346
# 4             4 2020-02-04 17:14:40.167
# ..          ...                     ...
# 209         210 2020-02-08 21:25:10.000
# 210         211 2020-02-08 21:28:39.000
# 211         212 2020-02-08 21:38:27.000
# 212         213 2020-02-08 21:47:19.000
# 213         214 2020-02-08 22:00:46.000
#
#                                                Promise  \
# 0                        delhi to be made a solar city
# 1                               20 new degree colleges
# 2                               20 new degree colleges
# 3    ramp up government schools to provide quality ...
# 4    ramp up government schools to provide quality ...
# ..                                                 ...
# 209                 taking care of our senior citizens
# 210                 taking care of our senior citizens
# 211                 taking care of our senior citizens
# 212                             controlling price rise
# 213                             controlling price rise
#
#                                             SubPromise Date of Update  \
# 0    we are committed to ensuring that 20 percent o...     2018-08-05
# 1    further we will double the existing seat capac...     2019-08-24
# 2    further we will double the existing seat capac...     2017-08-18
# 3    aap will build 500 new schools with a special ...     2020-01-09
# 4    aap will build 500 new schools with a special ...     2020-04-08
# ..                                                 ...            ...
# 209  the government will initiate a universal and n...            NaT
# 210  a minimum dignified amount indexed to inflatio...     2017-01-06
# 211  delays in disbursement and arbitrary decisions...     2018-07-31
# 212  in the retail and wholesale business, stringen...     2019-10-05
# 213  our government will use the its full strength ...     2016-09-23
#
#           Status                                        Description  \
# 0    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1    In Progress  Building of new campuses for Ambedkar universi...
# 2    In Progress  New University Campus for DTU opened up in Viv...
# 3           Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4           Done  Details of Swimming pools in two school situat...
# ..           ...                                                ...
# 209  Not Started                                                NaN
# 210         Done  For old age pension, those between the age gro...
# 211  In Progress  The Department to remit at old rates, all pens...
# 212         Done  The Food and Supplies minister directed his de...
# 213  In Progress  In the next 7 days, all ration stores should p...
#
#                                                  Title  \
# 0    Solarize Dwarka launched in BSES Rajdhani regi...
# 1                     Ambedkar University New Campuses
# 2                                   East Campus of DTU
# 3                     AAP builds 20,000 new classrooms
# 4    Delhi Govt Schools in West Vinod Nagar & Mayur...
# ..                                                 ...
# 209                                                NaN
# 210  Delhi Govt.’s decisions to bolster public tran...
# 211  Delhi CM approves Cabinet proposal to delink A...
# 212  Delhi minister orders more inspections to chec...
# 213  Delhi Govt. enforces strong measures to bring ...
#
#                                 Proof Documents/Images  \
# 0    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1    https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2    https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3    https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4    https://drive.google.com/open?id=1wp2zNWzsOGSi...
# ..                                                 ...
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
#
#                                              Proof URL  \
# 0                                http://solarbses.com/
# 1    https://www.thehindu.com/news/cities/Delhi/aud...
# 2    https://www.hindustantimes.com/delhi-news/east...
# 3    https://www.hindustantimes.com/education/aap-g...
# 4    https://timesofindia.indiatimes.com/city/delhi...
# ..                                                 ...
# 209                                                NaN
# 210  https://indianpoliticsandpolicy.wordpress.com/...
# 211  https://indianpoliticsandpolicy.wordpress.com/...
# 212  https://www.newindianexpress.com/cities/delhi/...
# 213  https://indianpoliticsandpolicy.wordpress.com/...
#
#                 Email Address Approved
# 0                         NaN      Yes
# 1                         NaN      Yes
# 2    adityapaul.aap@gmail.com      Yes
# 3    adityapaul.aap@gmail.com      Yes
# 4    adityapaul.aap@gmail.com      Yes
# ..                        ...      ...
# 209  soumya.pande99@gmail.com      NaN
# 210  soumya.pande99@gmail.com      NaN
# 211  soumya.pande99@gmail.com      NaN
# 212  soumya.pande99@gmail.com      NaN
# 213  soumya.pande99@gmail.com      NaN
#
# [214 rows x 12 columns]

# %%
old_and_new_updates = pd.concat([updates, oldupdates], sort=False)
# Out:
#                   Timestamp                              Promise  \
# 0   2020-02-03 18:38:44.301          Delhi To be Made Solar City
# 1   2020-02-04 15:33:03.322           Twenty New Degree Colleges
# 2   2020-02-04 16:34:14.222           Twenty New Degree Colleges
# 3   2020-02-04 16:53:02.346  Five Hundred New Government Schools
# 4   2020-02-04 17:14:40.167  Five Hundred New Government Schools
# ..                      ...                                  ...
# 209 2020-02-08 21:25:10.000   taking care of our senior citizens
# 210 2020-02-08 21:28:39.000   taking care of our senior citizens
# 211 2020-02-08 21:38:27.000   taking care of our senior citizens
# 212 2020-02-08 21:47:19.000               controlling price rise
# 213 2020-02-08 22:00:46.000               controlling price rise
#
#                                             SubPromise Date of Update  \
# 0    we are committed to ensuring that 20 percent o...     2018-08-05
# 1    further we will double the existing seat capac...     2019-08-24
# 2    further we will double the existing seat capac...     2017-08-18
# 3    aap will build 500 new schools with a special ...     2020-01-09
# 4    aap will build 500 new schools with a special ...     2020-04-08
# ..                                                 ...            ...
# 209  the government will initiate a universal and n...            NaT
# 210  a minimum dignified amount indexed to inflatio...     2017-01-06
# 211  delays in disbursement and arbitrary decisions...     2018-07-31
# 212  in the retail and wholesale business, stringen...     2019-10-05
# 213  our government will use the its full strength ...     2016-09-23
#
#           Status                                        Description  \
# 0    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1    In Progress  Building of new campuses for Ambedkar universi...
# 2    In Progress  New University Campus for DTU opened up in Viv...
# 3           Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4           Done  Details of Swimming pools in two school situat...
# ..           ...                                                ...
# 209  Not Started                                                NaN
# 210         Done  For old age pension, those between the age gro...
# 211  In Progress  The Department to remit at old rates, all pens...
# 212         Done  The Food and Supplies minister directed his de...
# 213  In Progress  In the next 7 days, all ration stores should p...
#
#                                                  Title  \
# 0    Solarize Dwarka launched in BSES Rajdhani regi...
# 1                     Ambedkar University New Campuses
# 2                                   East Campus of DTU
# 3                     AAP builds 20,000 new classrooms
# 4    Delhi Govt Schools in West Vinod Nagar & Mayur...
# ..                                                 ...
# 209                                                NaN
# 210  Delhi Govt.’s decisions to bolster public tran...
# 211  Delhi CM approves Cabinet proposal to delink A...
# 212  Delhi minister orders more inspections to chec...
# 213  Delhi Govt. enforces strong measures to bring ...
#
#                                 Proof Documents/Images  \
# 0    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1    https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2    https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3    https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4    https://drive.google.com/open?id=1wp2zNWzsOGSi...
# ..                                                 ...
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
#
#                                              Proof URL  \
# 0                                http://solarbses.com/
# 1    https://www.thehindu.com/news/cities/Delhi/aud...
# 2    https://www.hindustantimes.com/delhi-news/east...
# 3    https://www.hindustantimes.com/education/aap-g...
# 4    https://timesofindia.indiatimes.com/city/delhi...
# ..                                                 ...
# 209                                                NaN
# 210  https://indianpoliticsandpolicy.wordpress.com/...
# 211  https://indianpoliticsandpolicy.wordpress.com/...
# 212  https://www.newindianexpress.com/cities/delhi/...
# 213  https://indianpoliticsandpolicy.wordpress.com/...
#
#                 Email Address Approved  Unnamed: 0
# 0                         NaN      Yes         NaN
# 1                         NaN      Yes         NaN
# 2    adityapaul.aap@gmail.com      Yes         NaN
# 3    adityapaul.aap@gmail.com      Yes         NaN
# 4    adityapaul.aap@gmail.com      Yes         NaN
# ..                        ...      ...         ...
# 209  soumya.pande99@gmail.com      NaN       210.0
# 210  soumya.pande99@gmail.com      NaN       211.0
# 211  soumya.pande99@gmail.com      NaN       212.0
# 212  soumya.pande99@gmail.com      NaN       213.0
# 213  soumya.pande99@gmail.com      NaN       214.0
#
# [466 rows x 12 columns]

# %%
# Out:
# (466, 12)

# %%
merged_df = pd.merge(old_and_new_updates, ideal_promises, left_on='SubPromise', right_on = 'Sub promise')

# %%
merged_df
# Out:
#                   Timestamp                                      Promise_x  \
# 0   2020-02-03 18:38:44.301                    Delhi To be Made Solar City
# 1   2020-02-07 05:35:01.320                    Delhi To be Made Solar City
# 2   2020-02-07 22:27:42.408                    Delhi To be Made Solar City
# 3   2020-02-08 03:02:37.275                    Delhi To be Made Solar City
# 4   2020-02-03 18:38:44.301                  delhi to be made a solar city
# ..                      ...                                            ...
# 461 2020-02-16 14:54:46.000  Delhi's villages to receive special attention
# 462 2020-02-16 15:01:05.000  Delhi's villages to receive special attention
# 463 2020-02-16 15:17:19.000                         Pro-farmer land reform
# 464 2020-02-16 15:29:43.000                         Pro-farmer land reform
# 465 2020-02-16 15:54:54.000                         Pro-farmer land reform
#
#                                             SubPromise Date of Update  \
# 0    we are committed to ensuring that 20 percent o...     2018-08-05
# 1    we are committed to ensuring that 20 percent o...     2020-02-07
# 2    we are committed to ensuring that 20 percent o...     2018-01-08
# 3    we are committed to ensuring that 20 percent o...     2020-02-07
# 4    we are committed to ensuring that 20 percent o...     2018-08-05
# ..                                                 ...            ...
# 461  we will provide sports facilities in villages ...     2019-02-07
# 462  connectivity to rural delhi will be enhanced t...     2019-10-05
# 463  section 33 and 81 of the delhi land reform act...     2016-06-08
# 464  no land will be acquired in delhi’s villages w...            NaT
# 465  strong pressure would be exerted on the centra...     2015-07-15
#
#           Status                                        Description  \
# 0    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1    In Progress  As of Nov 2019, Delhi had only 146 MW of rooft...
# 2        Started  BSES, in partnership with USAID-PACE-D and Ind...
# 3    In Progress  Comprehensive solar policy targets 2 GW solar ...
# 4    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# ..           ...                                                ...
# 461  In Progress  The proposed complex will include a synthetic ...
# 462         Done  Trains will be available on the corridor at a ...
# 463  In Progress  A notice issued by the Revenue Department said...
# 464  Not Started                                                NaN
# 465         Done  "The BJP had then whole-heartedly supported th...
#
#                                                  Title  \
# 0    Solarize Dwarka launched in BSES Rajdhani regi...
# 1    Ambitious target set under the Solar Policy, r...
# 2                       Solar City Initiative Launched
# 3    New Solar Policy in Delhi promotes renewable e...
# 4    Solarize Dwarka launched in BSES Rajdhani regi...
# ..                                                 ...
# 461  Delhi government nod for Rs 140 crore ultra-mo...
# 462  Grey Line opnes, to link rural Najafgarh with ...
# 463  AAP Govt to change agri land use to legalise 1...
# 464                                                NaN
# 465  Kejriwal opposes land bill,Centre's 'impingeme...
#
#                                 Proof Documents/Images  \
# 0    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# ..                                                 ...
# 461                                                NaN
# 462                                                NaN
# 463                                                NaN
# 464                                                NaN
# 465                                                NaN
#
#                                              Proof URL  \
# 0                                http://solarbses.com/
# 1    https://www.pv-magazine-india.com/2019/11/29/m...
# 2    https://www.thehindu.com/news/cities/Delhi/sol...
# 3    http://ipgcl-ppcl.gov.in/documents/renewable/2...
# 4                                http://solarbses.com/
# ..                                                 ...
# 461  https://www.hindustantimes.com/delhi-news/delh...
# 462  https://timesofindia.indiatimes.com/city/delhi...
# 463  https://www.dailypioneer.com/2016/page1/aap-go...
# 464                                                NaN
# 465  https://www.business-standard.com/article/pti-...
#
#                   Email Address Approved  Unnamed: 0  Sr No  \
# 0                           NaN      Yes         NaN      8
# 1    utkarshpatel1992@gmail.com      NaN         NaN      8
# 2         nettedstars@gmail.com      NaN         NaN      8
# 3    raavi.aggarwal95@gmail.com      NaN         NaN      8
# 4                           NaN      Yes         0.0      8
# ..                          ...      ...         ...    ...
# 461    soumya.pande99@gmail.com      NaN         NaN     36
# 462    soumya.pande99@gmail.com      NaN         NaN     36
# 463    soumya.pande99@gmail.com      NaN         NaN     37
# 464    soumya.pande99@gmail.com      NaN         NaN     37
# 465    soumya.pande99@gmail.com      NaN         NaN     37
#
#                                          Promise_y  \
# 0                    delhi to be made a solar city
# 1                    delhi to be made a solar city
# 2                    delhi to be made a solar city
# 3                    delhi to be made a solar city
# 4                    delhi to be made a solar city
# ..                                             ...
# 461  delhi's villages to receive special attention
# 462  delhi's villages to receive special attention
# 463                         pro-farmer land reform
# 464                         pro-farmer land reform
# 465                         pro-farmer land reform
#
#                                            Sub promise  \
# 0    we are committed to ensuring that 20 percent o...
# 1    we are committed to ensuring that 20 percent o...
# 2    we are committed to ensuring that 20 percent o...
# 3    we are committed to ensuring that 20 percent o...
# 4    we are committed to ensuring that 20 percent o...
# ..                                                 ...
# 461  we will provide sports facilities in villages ...
# 462  connectivity to rural delhi will be enhanced t...
# 463  section 33 and 81 of the delhi land reform act...
# 464  no land will be acquired in delhi’s villages w...
# 465  strong pressure would be exerted on the centra...
#
#                                             Unnamed: 3            Department  \
# 0    Delhi to be made a Solar CIty__We are committe...      Power Department
# 1    Delhi to be made a Solar CIty__We are committe...      Power Department
# 2    Delhi to be made a Solar CIty__We are committe...      Power Department
# 3    Delhi to be made a Solar CIty__We are committe...      Power Department
# 4    Delhi to be made a Solar CIty__We are committe...      Power Department
# ..                                                 ...                   ...
# 461  Delhi's villages to receive special attention_...  Education Department
# 462  Delhi's villages to receive special attention_...  Transport Department
# 463  Pro-farmer land reform__Section 33 and 81 of t...        Law Department
# 464  Pro-farmer land reform__No land will be acquir...    Revenue Department
# 465  Pro-farmer land reform__Strong pressure would ...        Delhi Assembly
#
#           Outcome  __
# 0          Energy NaN
# 1          Energy NaN
# 2          Energy NaN
# 3          Energy NaN
# 4          Energy NaN
# ..            ...  ..
# 461  Rural Reform NaN
# 462  Rural Reform NaN
# 463  Rural Reform NaN
# 464  Rural Reform NaN
# 465  Rural Reform NaN
#
# [466 rows x 19 columns]

# %%
merged_df.drop(merged_df.columns[merged_df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
merged_df.columns
# Out:
# Index(['Timestamp', 'Promise_x', 'SubPromise', 'Date of Update', 'Status',
#        'Description', 'Title', 'Proof Documents/Images', 'Proof URL',
#        'Email Address', 'Approved', 'Sr No', 'Promise_y', 'Sub promise',
#        'Department', 'Outcome', '__'],
#       dtype='object')

# %%
merged_df.drop(['Promise_x', '__', 'Sr No'],axis=1, inplace=True)
merged_df = merged_df.rename(columns={'Promise_y': 'Promise'})

# %%
merged_df.to_excel('../assets/data/updates.xlsx')
# Out:
# /home/antagonist/miniconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:915: UserWarning: Ignoring URL 'https://drive.google.com/open?id=1FPaJO1OIcNXpypImQukzTyXvkV7mWXJA,%20https://drive.google.com/open?id=1M6BhhO_7X0oJAtY5iEE5tUSHz5bfpSSP,%20https://drive.google.com/open?id=1aS8Fb0FdkVYecIkd4hR26w9PdfHh115X,%20https://drive.google.com/open?id=1GqXCSr0OFFdOts9VuL2Z3aIiJrXTvSFG,%20https://drive.google.com/open?id=1nExF3i_a5_2Xqh1_rY7ZnxFZj8Qn5ZSw' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
