# %% [markdown]
# ### This notebook code that maps the Promises from the updates google form to the sheet Roshan Shared

# %%
import pandas as pd

# %%
ideal_promises = pd.read_excel('../assets/data/Promises.xlsx')

# %%
ideal_promises.to_excel('newPromises.xlsx', index=None)

# %%
ideal_promises.Promise = ideal_promises.Promise.apply(lambda x: x.lower().strip())

# %%
ideal_promises['Sub promise'] = ideal_promises['Sub promise'].apply(lambda x: x.lower().strip())

# %%
updates = pd.read_excel('../assets/data/newResponses.xlsx')

# %%
updates.shape
# Out:
# (250, 11)

# %%
updates.Promise = updates.Promise.apply(lambda x: x.lower().strip())

# %%
ideal_promises.head()
# Out:
#    Sr No          Promise                                        Sub promise  \
# 0      1  jan lokpal bill  aam aadmi party resolves to legislate the delh...
# 1      1  jan lokpal bill  this will ensure a time-bound investigation in...
# 2      1  jan lokpal bill  the delhi lokpal will have the power to initia...
# 3      1  jan lokpal bill  a citizens’ charter shall be introduced in all...
# 4      1  jan lokpal bill  whistleblowers will be provided protection and...
#
#                                           Unnamed: 3              Department  \
# 0  Jan Lokpal Bill__Aam Aadmi Party resolves to l...          Delhi Assembly
# 1  Jan Lokpal Bill__This will ensure a time-bound...  Anti Corruption Bureau
# 2  Jan Lokpal Bill__The Delhi Lokpal will have th...          Delhi Assembly
# 3  Jan Lokpal Bill__A Citizens’ Charter shall be ...          Delhi Assembly
# 4  Jan Lokpal Bill__Whistleblowers will be provid...      Finance Department
#
#       Outcome  __
# 0  Governance NaN
# 1  Governance NaN
# 2  Governance NaN
# 3  Governance NaN
# 4  Governance NaN

# %%
correct_subpromises = ideal_promises['Sub promise'].unique()

# %%
correct_promises = set([promise.lower() for promise in ideal_promises.Promise.unique()])

# %%
assert len(correct_promises) == 70

# %%
updates_promises = set([promise.lower() for promise in updates.Promise.unique()])

# %%
errors = updates_promises - correct_promises

# %%
from fuzzywuzzy import process

# %%
corrections = {k:process.extract(k, correct_promises, limit=1)[0][0] for k in errors}

# %%
corrections
# Out:
# {'fair and transparent water pricing': 'fair transparent water pricing',
#  'transparency in schools admission': 'tranparency in school admissions',
#  'delhi to be startup hub': 'delhi to be start up hub',
#  'cctvs in public spaces and buses': "cctv's in public spaces & buses",
#  'twenty new degree colleges': '20 new degree colleges',
#  'delhi janlokpal bill:': "delhi's villages to receive special attention",
#  'delhi to be made solar city': 'delhi to be made a solar city',
#  'crackdown on water mafia': 'crack down on water mafia',
#  'wifi delhi': 'wi-fi delhi',
#  'just and fair policy for e rickshaws': 'just and fair policy for e-rickshaws',
#  'water from munak canaal': 'water from munak canal',
#  'five hundred new government schools': '20 new degree colleges',
#  'promote rainwater harvesting': 'promote rain water harvesting',
#  'increased spending on education and healthcare': 'increase spending on education & healthcare',
#  'justice for the victims of 1984': 'justice for victims of anti-sikh 1984 carnage',
#  'build 2,00,000 public toilets': 'metro rail 2.0',
#  'contractual posts to be regularized': 'contractual posts to be regularised',
#  'higher education gurantee scheme': 'higher education guarantee scheme',
#  'large scale expansion inbus service': 'large scale expansion in bus services',
#  'water as a right': 'water as right',
#  'fair arrangement for auto drivers': 'fair arrangement for autodrivers'}

# %%
maps = {k:k for k in updates.Promise.unique()}
maps.update(corrections)

# %%
updates['Promise'] = updates['Promise'].map(maps)

# %%
updates['SubPromise'] = updates['SubPromise'].apply(lambda x: x.split('__')[-1].lower().strip())

# %%
updates.head()
# Out:
#                 Timestamp                        Promise  \
# 0 2020-02-03 18:38:44.301  delhi to be made a solar city
# 1 2020-02-04 15:33:03.322         20 new degree colleges
# 2 2020-02-04 16:34:14.222         20 new degree colleges
# 3 2020-02-04 16:53:02.346         20 new degree colleges
# 4 2020-02-04 17:14:40.167         20 new degree colleges
#
#                                           SubPromise Date of Update  \
# 0  we are committed to ensuring that 20 percent o...     2018-08-05
# 1  further we will double the existing seat capac...     2019-08-24
# 2  further we will double the existing seat capac...     2017-08-18
# 3  aap will build 500 new schools with a special ...     2020-01-09
# 4  aap will build 500 new schools with a special ...     2020-04-08
#
#         Status                                        Description  \
# 0  In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1  In Progress  Building of new campuses for Ambedkar universi...
# 2  In Progress  New University Campus for DTU opened up in Viv...
# 3         Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4         Done  Details of Swimming pools in two school situat...
#
#                                                Title  \
# 0  Solarize Dwarka launched in BSES Rajdhani regi...
# 1                   Ambedkar University New Campuses
# 2                                 East Campus of DTU
# 3                   AAP builds 20,000 new classrooms
# 4  Delhi Govt Schools in West Vinod Nagar & Mayur...
#
#                               Proof Documents/Images  \
# 0  https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1  https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2  https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3  https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4  https://drive.google.com/open?id=1wp2zNWzsOGSi...
#
#                                            Proof URL  \
# 0                              http://solarbses.com/
# 1  https://www.thehindu.com/news/cities/Delhi/aud...
# 2  https://www.hindustantimes.com/delhi-news/east...
# 3  https://www.hindustantimes.com/education/aap-g...
# 4  https://timesofindia.indiatimes.com/city/delhi...
#
#               Email Address Approved
# 0                       NaN      Yes
# 1                       NaN      Yes
# 2  adityapaul.aap@gmail.com      Yes
# 3  adityapaul.aap@gmail.com      Yes
# 4  adityapaul.aap@gmail.com      Yes

# %%
subpromise_errors = set(updates['SubPromise'].unique()) - set(correct_subpromises)

# %%
corrections = {k:process.extract(k, correct_subpromises, limit=2) for k in subpromise_errors}

# %%
len(subpromise_errors)
subpromise_errors
# Out:
# {'private tankers will be allowed to operate under the guidelines framed by our government. this will protect the consumers from exorbitant pricing and illegal practices of private tanker operators.',
#  'slum dwellers will be provided plots or flats in the same location as the existing slums. if that is not possible, they will be rehabilitated in the closest possible location.'}

# %%
updates[updates['SubPromise'].isin(subpromise_errors)].to_excel('soumya_corrections.xlsx')

# %%
subpromise_error_indices = updates[updates['SubPromise'].isin(subpromise_errors)].index

# %%
updates = updates.drop(subpromise_error_indices)

# %%
updates.to_excel('newupdates.xlsx')

# %%
updates.head()
# Out:
#                 Timestamp                        Promise  \
# 0 2020-02-03 18:38:44.301  delhi to be made a solar city
# 1 2020-02-04 15:33:03.322         20 new degree colleges
# 2 2020-02-04 16:34:14.222         20 new degree colleges
# 3 2020-02-04 16:53:02.346         20 new degree colleges
# 4 2020-02-04 17:14:40.167         20 new degree colleges
#
#                                           SubPromise Date of Update  \
# 0  we are committed to ensuring that 20 percent o...     2018-08-05
# 1  further we will double the existing seat capac...     2019-08-24
# 2  further we will double the existing seat capac...     2017-08-18
# 3  aap will build 500 new schools with a special ...     2020-01-09
# 4  aap will build 500 new schools with a special ...     2020-04-08
#
#         Status                                        Description  \
# 0  In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1  In Progress  Building of new campuses for Ambedkar universi...
# 2  In Progress  New University Campus for DTU opened up in Viv...
# 3         Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4         Done  Details of Swimming pools in two school situat...
#
#                                                Title  \
# 0  Solarize Dwarka launched in BSES Rajdhani regi...
# 1                   Ambedkar University New Campuses
# 2                                 East Campus of DTU
# 3                   AAP builds 20,000 new classrooms
# 4  Delhi Govt Schools in West Vinod Nagar & Mayur...
#
#                               Proof Documents/Images  \
# 0  https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1  https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2  https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3  https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4  https://drive.google.com/open?id=1wp2zNWzsOGSi...
#
#                                            Proof URL  \
# 0                              http://solarbses.com/
# 1  https://www.thehindu.com/news/cities/Delhi/aud...
# 2  https://www.hindustantimes.com/delhi-news/east...
# 3  https://www.hindustantimes.com/education/aap-g...
# 4  https://timesofindia.indiatimes.com/city/delhi...
#
#               Email Address Approved
# 0                       NaN      Yes
# 1                       NaN      Yes
# 2  adityapaul.aap@gmail.com      Yes
# 3  adityapaul.aap@gmail.com      Yes
# 4  adityapaul.aap@gmail.com      Yes

# %%
ideal_promises.head()
# Out:
#    Sr No          Promise                                        Sub promise  \
# 0      1  jan lokpal bill  aam aadmi party resolves to legislate the delh...
# 1      1  jan lokpal bill  this will ensure a time-bound investigation in...
# 2      1  jan lokpal bill  the delhi lokpal will have the power to initia...
# 3      1  jan lokpal bill  a citizens’ charter shall be introduced in all...
# 4      1  jan lokpal bill  whistleblowers will be provided protection and...
#
#                                           Unnamed: 3              Department  \
# 0  Jan Lokpal Bill__Aam Aadmi Party resolves to l...          Delhi Assembly
# 1  Jan Lokpal Bill__This will ensure a time-bound...  Anti Corruption Bureau
# 2  Jan Lokpal Bill__The Delhi Lokpal will have th...          Delhi Assembly
# 3  Jan Lokpal Bill__A Citizens’ Charter shall be ...          Delhi Assembly
# 4  Jan Lokpal Bill__Whistleblowers will be provid...      Finance Department
#
#       Outcome  __
# 0  Governance NaN
# 1  Governance NaN
# 2  Governance NaN
# 3  Governance NaN
# 4  Governance NaN

# %%
old_updates = pd.read_excel('../assets/data/old/updates.xlsx')
# Out:
#                       Timestamp                              Promise  \
# 0    2020-02-03 18:38:44.301000          Delhi To be Made Solar City
# 1    2020-02-04 15:33:03.322000           Twenty New Degree Colleges
# 2    2020-02-04 16:34:14.222000           Twenty New Degree Colleges
# 3    2020-02-04 16:53:02.346000  Five Hundred New Government Schools
# 4    2020-02-04 17:14:40.167000  Five Hundred New Government Schools
# ..                          ...                                  ...
# 230         2020-02-12 17:25:55                          Swaraj Bill
# 231         2020-02-12 17:26:32                          Swaraj Bill
# 232                    15:30:55                          Swaraj Bill
# 233                    15:41:45                          Swaraj Bill
# 234                    15:43:31                          Swaraj Bill
#
#                                             SubPromise Date of Update  \
# 0    Delhi to be made a Solar CIty__We are committe...     2018-08-05
# 1    20 New Degree Colleges__Further we will double...     2019-08-24
# 2    20 New Degree Colleges__Further we will double...     2017-08-18
# 3    500 New Govt Schools__AAP will build 500 new s...     2020-01-09
# 4    500 New Govt Schools__AAP will build 500 new s...     2020-04-08
# ..                                                 ...            ...
# 230  Swaraj Bill__Important documents such as birth...            NaT
# 231  Swaraj Bill__The list of beneficiaries of gove...            NaT
# 232  Swaraj Bill__Opening an alcohol shop or outlet...     2016-08-17
# 233  Swaraj Bill__In a few years, when the function...     2017-08-09
# 234  Swaraj Bill__In a few years, when the Mohalla ...     2017-08-09
#
#           Status                                        Description  \
# 0    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1    In Progress  Building of new campuses for Ambedkar universi...
# 2    In Progress  New University Campus for DTU opened up in Viv...
# 3           Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4           Done  Details of Swimming pools in two school situat...
# ..           ...                                                ...
# 230  In Progress  Mohalla Sabhas will also be able to take decis...
# 231  In Progress  Mohalla Sabhas will also be able to take decis...
# 232         Done  The recently constituted Mohalla Sabhas will d...
# 233  Not Started  Rs 350 crore was passed in the budget for Moha...
# 234  Not Started  Rs 350 crore was passed in the budget for Moha...
#
#                                                  Title  \
# 0    Solarize Dwarka launched in BSES Rajdhani regi...
# 1                     Ambedkar University New Campuses
# 2                                   East Campus of DTU
# 3                     AAP builds 20,000 new classrooms
# 4    Delhi Govt Schools in West Vinod Nagar & Mayur...
# ..                                                 ...
# 230                                 FAQs Mohalla Sabha
# 231                                 FAQs Mohalla Sabha
# 232  Delhi’s new excise policy hands democratic pow...
# 233  AAP requests Anil Baijal to sign Bill on Mohal...
# 234  AAP requests Anil Baijal to sign Bill on Mohal...
#
#                                 Proof Documents/Images  \
# 0    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1    https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2    https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3    https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4    https://drive.google.com/open?id=1wp2zNWzsOGSi...
# ..                                                 ...
# 230                                                NaN
# 231                                                NaN
# 232  https://indianpoliticsandpolicy.wordpress.com/...
# 233                                                NaN
# 234                                                NaN
#
#                                              Proof URL  \
# 0                                http://solarbses.com/
# 1    https://www.thehindu.com/news/cities/Delhi/aud...
# 2    https://www.hindustantimes.com/delhi-news/east...
# 3    https://www.hindustantimes.com/education/aap-g...
# 4    https://timesofindia.indiatimes.com/city/delhi...
# ..                                                 ...
# 230          http://mohallasabha.delhi.gov.in/faq.html
# 231          http://mohallasabha.delhi.gov.in/faq.html
# 232                                                NaN
# 233  https://www.ndtv.com/delhi-news/aap-requests-a...
# 234  https://www.ndtv.com/delhi-news/aap-requests-a...
#
#                 Email Address Approved
# 0                         NaN      Yes
# 1                         NaN      Yes
# 2    adityapaul.aap@gmail.com      Yes
# 3    adityapaul.aap@gmail.com      Yes
# 4    adityapaul.aap@gmail.com      Yes
# ..                        ...      ...
# 230  soumya.pande99@gmail.com      NaN
# 231  soumya.pande99@gmail.com      NaN
# 232  soumya.pande99@gmail.com      NaN
# 233  soumya.pande99@gmail.com      NaN
# 234  soumya.pande99@gmail.com      NaN
#
# [235 rows x 11 columns]

# %%
old_updates['SubPromise'] = old_updates['SubPromise'].apply(lambda x: x.split('__')[-1].lower().strip())

# %%
old_and_new_updates = pd.concat([updates, old_updates])
old_and_new_updates
# Out:
#                       Timestamp                        Promise  \
# 0    2020-02-03 18:38:44.301000  delhi to be made a solar city
# 1    2020-02-04 15:33:03.322000         20 new degree colleges
# 2    2020-02-04 16:34:14.222000         20 new degree colleges
# 3    2020-02-04 16:53:02.346000         20 new degree colleges
# 4    2020-02-04 17:14:40.167000         20 new degree colleges
# ..                          ...                            ...
# 230         2020-02-12 17:25:55                    Swaraj Bill
# 231         2020-02-12 17:26:32                    Swaraj Bill
# 232                    15:30:55                    Swaraj Bill
# 233                    15:41:45                    Swaraj Bill
# 234                    15:43:31                    Swaraj Bill
#
#                                             SubPromise Date of Update  \
# 0    we are committed to ensuring that 20 percent o...     2018-08-05
# 1    further we will double the existing seat capac...     2019-08-24
# 2    further we will double the existing seat capac...     2017-08-18
# 3    aap will build 500 new schools with a special ...     2020-01-09
# 4    aap will build 500 new schools with a special ...     2020-04-08
# ..                                                 ...            ...
# 230  important documents such as birth, death, cast...            NaT
# 231  the list of beneficiaries of government scheme...            NaT
# 232  opening an alcohol shop or outlet in the neigh...     2016-08-17
# 233  in a few years, when the functioning of mohall...     2017-08-09
# 234  in a few years, when the mohalla sabhas become...     2017-08-09
#
#           Status                                        Description  \
# 0    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1    In Progress  Building of new campuses for Ambedkar universi...
# 2    In Progress  New University Campus for DTU opened up in Viv...
# 3           Done  The AAP govt opened 20,000 classrooms in Delhi...
# 4           Done  Details of Swimming pools in two school situat...
# ..           ...                                                ...
# 230  In Progress  Mohalla Sabhas will also be able to take decis...
# 231  In Progress  Mohalla Sabhas will also be able to take decis...
# 232         Done  The recently constituted Mohalla Sabhas will d...
# 233  Not Started  Rs 350 crore was passed in the budget for Moha...
# 234  Not Started  Rs 350 crore was passed in the budget for Moha...
#
#                                                  Title  \
# 0    Solarize Dwarka launched in BSES Rajdhani regi...
# 1                     Ambedkar University New Campuses
# 2                                   East Campus of DTU
# 3                     AAP builds 20,000 new classrooms
# 4    Delhi Govt Schools in West Vinod Nagar & Mayur...
# ..                                                 ...
# 230                                 FAQs Mohalla Sabha
# 231                                 FAQs Mohalla Sabha
# 232  Delhi’s new excise policy hands democratic pow...
# 233  AAP requests Anil Baijal to sign Bill on Mohal...
# 234  AAP requests Anil Baijal to sign Bill on Mohal...
#
#                                 Proof Documents/Images  \
# 0    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1    https://drive.google.com/open?id=1RqFvgsnm4wYo...
# 2    https://drive.google.com/open?id=1xcXa5znsMEjO...
# 3    https://drive.google.com/open?id=1My2P9B7qDRNG...
# 4    https://drive.google.com/open?id=1wp2zNWzsOGSi...
# ..                                                 ...
# 230                                                NaN
# 231                                                NaN
# 232  https://indianpoliticsandpolicy.wordpress.com/...
# 233                                                NaN
# 234                                                NaN
#
#                                              Proof URL  \
# 0                                http://solarbses.com/
# 1    https://www.thehindu.com/news/cities/Delhi/aud...
# 2    https://www.hindustantimes.com/delhi-news/east...
# 3    https://www.hindustantimes.com/education/aap-g...
# 4    https://timesofindia.indiatimes.com/city/delhi...
# ..                                                 ...
# 230          http://mohallasabha.delhi.gov.in/faq.html
# 231          http://mohallasabha.delhi.gov.in/faq.html
# 232                                                NaN
# 233  https://www.ndtv.com/delhi-news/aap-requests-a...
# 234  https://www.ndtv.com/delhi-news/aap-requests-a...
#
#                 Email Address Approved
# 0                         NaN      Yes
# 1                         NaN      Yes
# 2    adityapaul.aap@gmail.com      Yes
# 3    adityapaul.aap@gmail.com      Yes
# 4    adityapaul.aap@gmail.com      Yes
# ..                        ...      ...
# 230  soumya.pande99@gmail.com      NaN
# 231  soumya.pande99@gmail.com      NaN
# 232  soumya.pande99@gmail.com      NaN
# 233  soumya.pande99@gmail.com      NaN
# 234  soumya.pande99@gmail.com      NaN
#
# [483 rows x 11 columns]

# %%
merged_df = pd.merge(old_and_new_updates, ideal_promises, left_on='SubPromise', right_on = 'Sub promise')
merged_df
# Out:
#                       Timestamp  \
# 0    2020-02-03 18:38:44.301000
# 1    2020-02-07 05:35:01.320000
# 2    2020-02-07 22:27:42.408000
# 3    2020-02-08 03:02:37.275000
# 4    2020-02-03 18:38:44.301000
# ..                          ...
# 457         2020-02-16 14:54:46
# 458         2020-02-16 15:01:05
# 459         2020-02-16 15:17:19
# 460         2020-02-16 15:29:43
# 461         2020-02-16 15:54:54
#
#                                          Promise_x  \
# 0                    delhi to be made a solar city
# 1                    delhi to be made a solar city
# 2                    delhi to be made a solar city
# 3                    delhi to be made a solar city
# 4                      Delhi To be Made Solar City
# ..                                             ...
# 457  delhi's villages to receive special attention
# 458  delhi's villages to receive special attention
# 459                         pro-farmer land reform
# 460                         pro-farmer land reform
# 461                         pro-farmer land reform
#
#                                             SubPromise Date of Update  \
# 0    we are committed to ensuring that 20 percent o...     2018-08-05
# 1    we are committed to ensuring that 20 percent o...     2020-02-07
# 2    we are committed to ensuring that 20 percent o...     2018-01-08
# 3    we are committed to ensuring that 20 percent o...     2020-02-07
# 4    we are committed to ensuring that 20 percent o...     2018-08-05
# ..                                                 ...            ...
# 457  we will provide sports facilities in villages ...     2019-02-07
# 458  connectivity to rural delhi will be enhanced t...     2019-10-05
# 459  section 33 and 81 of the delhi land reform act...     2016-06-08
# 460  no land will be acquired in delhi’s villages w...            NaT
# 461  strong pressure would be exerted on the centra...     2015-07-15
#
#           Status                                        Description  \
# 0    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# 1    In Progress  As of Nov 2019, Delhi had only 146 MW of rooft...
# 2        Started  BSES, in partnership with USAID-PACE-D and Ind...
# 3    In Progress  Comprehensive solar policy targets 2 GW solar ...
# 4    In Progress  BRPL aims to bring the benefit of Rooftop Sola...
# ..           ...                                                ...
# 457  In Progress  The proposed complex will include a synthetic ...
# 458         Done  Trains will be available on the corridor at a ...
# 459  In Progress  A notice issued by the Revenue Department said...
# 460  Not Started                                                NaN
# 461         Done  "The BJP had then whole-heartedly supported th...
#
#                                                  Title  \
# 0    Solarize Dwarka launched in BSES Rajdhani regi...
# 1    Ambitious target set under the Solar Policy, r...
# 2                       Solar City Initiative Launched
# 3    New Solar Policy in Delhi promotes renewable e...
# 4    Solarize Dwarka launched in BSES Rajdhani regi...
# ..                                                 ...
# 457  Delhi government nod for Rs 140 crore ultra-mo...
# 458  Grey Line opnes, to link rural Najafgarh with ...
# 459  AAP Govt to change agri land use to legalise 1...
# 460                                                NaN
# 461  Kejriwal opposes land bill,Centre's 'impingeme...
#
#                                 Proof Documents/Images  \
# 0    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://drive.google.com/open?id=1mhcUrdxLr3LA...
# ..                                                 ...
# 457                                                NaN
# 458                                                NaN
# 459                                                NaN
# 460                                                NaN
# 461                                                NaN
#
#                                              Proof URL  \
# 0                                http://solarbses.com/
# 1    https://www.pv-magazine-india.com/2019/11/29/m...
# 2    https://www.thehindu.com/news/cities/Delhi/sol...
# 3    http://ipgcl-ppcl.gov.in/documents/renewable/2...
# 4                                http://solarbses.com/
# ..                                                 ...
# 457  https://www.hindustantimes.com/delhi-news/delh...
# 458  https://timesofindia.indiatimes.com/city/delhi...
# 459  https://www.dailypioneer.com/2016/page1/aap-go...
# 460                                                NaN
# 461  https://www.business-standard.com/article/pti-...
#
#                   Email Address Approved  Sr No  \
# 0                           NaN      Yes      8
# 1    utkarshpatel1992@gmail.com      NaN      8
# 2         nettedstars@gmail.com      NaN      8
# 3    raavi.aggarwal95@gmail.com      NaN      8
# 4                           NaN      Yes      8
# ..                          ...      ...    ...
# 457    soumya.pande99@gmail.com      NaN     36
# 458    soumya.pande99@gmail.com      NaN     36
# 459    soumya.pande99@gmail.com      NaN     37
# 460    soumya.pande99@gmail.com      NaN     37
# 461    soumya.pande99@gmail.com      NaN     37
#
#                                          Promise_y  \
# 0                    delhi to be made a solar city
# 1                    delhi to be made a solar city
# 2                    delhi to be made a solar city
# 3                    delhi to be made a solar city
# 4                    delhi to be made a solar city
# ..                                             ...
# 457  delhi's villages to receive special attention
# 458  delhi's villages to receive special attention
# 459                         pro-farmer land reform
# 460                         pro-farmer land reform
# 461                         pro-farmer land reform
#
#                                            Sub promise  \
# 0    we are committed to ensuring that 20 percent o...
# 1    we are committed to ensuring that 20 percent o...
# 2    we are committed to ensuring that 20 percent o...
# 3    we are committed to ensuring that 20 percent o...
# 4    we are committed to ensuring that 20 percent o...
# ..                                                 ...
# 457  we will provide sports facilities in villages ...
# 458  connectivity to rural delhi will be enhanced t...
# 459  section 33 and 81 of the delhi land reform act...
# 460  no land will be acquired in delhi’s villages w...
# 461  strong pressure would be exerted on the centra...
#
#                                             Unnamed: 3            Department  \
# 0    Delhi to be made a Solar CIty__We are committe...      Power Department
# 1    Delhi to be made a Solar CIty__We are committe...      Power Department
# 2    Delhi to be made a Solar CIty__We are committe...      Power Department
# 3    Delhi to be made a Solar CIty__We are committe...      Power Department
# 4    Delhi to be made a Solar CIty__We are committe...      Power Department
# ..                                                 ...                   ...
# 457  Delhi's villages to receive special attention_...  Education Department
# 458  Delhi's villages to receive special attention_...  Transport Department
# 459  Pro-farmer land reform__Section 33 and 81 of t...        Law Department
# 460  Pro-farmer land reform__No land will be acquir...    Revenue Department
# 461  Pro-farmer land reform__Strong pressure would ...        Delhi Assembly
#
#           Outcome  __
# 0          Energy NaN
# 1          Energy NaN
# 2          Energy NaN
# 3          Energy NaN
# 4          Energy NaN
# ..            ...  ..
# 457  Rural Reform NaN
# 458  Rural Reform NaN
# 459  Rural Reform NaN
# 460  Rural Reform NaN
# 461  Rural Reform NaN
#
# [462 rows x 18 columns]

# %%
merged_df.shape
# Out:
# (462, 18)

# %%
merged_df.to_excel('mergedOldAndNewUpdates.xlsx', index=None)
